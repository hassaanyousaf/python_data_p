# %%
import pandas as pd
import seaborn as sns
import ast
import matplotlib.pyplot as plt
from datasets import load_dataset
dataset=load_dataset('lukebarousse/data_jobs')
df=dataset["train"].to_pandas()
df['job_posted_date']=pd.to_datetime(df.job_posted_date)
df["job_skills"]=df["job_skills"].apply(lambda x:ast.literal_eval(x) if pd.notna(x) else x)

# %%
df_da_us=df[ (df['job_country']=='United States' )& (df['job_title_short']=='Data Analyst' )]

# %%
barplot=df["job_location"].value_counts().head(10).to_frame()
sns.barplot(data=barplot, x='count', y='job_location',hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts for Job Location in the US')
plt.ylabel('Job title')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
columns = ['job_work_from_home', 'job_no_degree_mention', 'job_health_insurance']
titles = ['Work from Home Offered', 'Degree Requirement', 'Health Insurance Offered']

fig, ax = plt.subplots(1, 3)

for i in range(3):
    ax[i].pie(df_da_us[columns[i]].value_counts(), startangle=90, autopct='%1.1f%%', labels=['False', 'True'])
    ax[i].set_title(titles[i])

plt.tight_layout()
plt.show()

# %%
barplot=df['company_name'].value_counts().head(10).to_frame()
sns.barplot(data=barplot, x='count', y='company_name',hue='count', palette='dark:b_r', legend=False)
sns.despine()
plt.title('Counts for Job companies in the US')
plt.ylabel('Job title')
plt.xlabel('')
# Out:
# Text(0.5, 0, '')
